# %%
import numpy as np
import pandas as pd
import os  # for general OS functions if needed
import re




##########
# This file is used to clean and consolidate daily parking transaction excel sheets.
# As of 02/16/2025, the excel files passed must contain multiple sheets within to properly consolidate.
# Use consolidate_Folder(file_path) to combine all transactions in a local folder.
##########




#@title FindHeader, FindFooter, FindStation Rows code


# Check where the first row of transactions begin
def findHeader(df):
    # Search for the header row of the sheet and return the row number
    row = df.index[df.iloc[:, 0] == "Entry Time"]
    return row[0] + 1  # Returns the row number of the header row, you should skip to row[0]-1


# Check where the last row of transactions begin
def findFooter(df):
    # Search for the footer row of the sheet and return the number of footer rows to skip
    row = df.index[df.iloc[:, 0].str.contains("Totals", case=False, na=False)]
    totalrows = len(df)
    numFooterRows = totalrows - row[0]
    return numFooterRows


# Check to see if a sheet has a station and returns row where station is
def findStation(df):
    row = df.index[df.iloc[:, 0].str.contains("Station", case=False, na=False)]
    if row.empty:
        return False
    else:
        return row[0]




# Consolidated Code


# Create a singular process code
def processSheetwithHeader(eFile, sName, oFile, adjust_footer=False):
    print("Processing with header:", eFile)
    df = pd.read_excel(eFile, sheet_name=sName)
    rowHeader = findHeader(df)
    rowFooter = findFooter(df)
    StationRow = findStation(df)


    # Pull out station value for sheet if it exists
    if StationRow != False:
        station = df.iloc[StationRow, 0]
        start_index = station.find("Station: ") + len("Station: ")  # Index of 'A' in 'A21'
        end_index = station.find("-", start_index)  # Index of '-' character
        Station = station[start_index:end_index]


    df = pd.read_excel(eFile, sheet_name=sName, skiprows=rowHeader, skipfooter=rowFooter+1)
    if StationRow != False:  # Create a new column to specify Exit Station
        df.insert(df.columns.get_loc("Prev Stn") + 1, 'Station', Station)
    df.rename(columns={'Trans Time': 'Transaction Time',
                       'Media\n': 'Media',
                       'Media ID\n': 'Media',
                       'Prev Stn': 'Previous Station',
                       'Trans Type': 'Transaction Type'}, inplace=True)
    # You can add or delete columns that you would like to include/exclude in the final df
    df = df[['Entry Time', 'Transaction Time', 'Previous Station', 'Station', 'Media', 'Transaction Type', 'Revenue']]
    df.to_csv(oFile, mode="a", index=False, header=True)  # Write to the correct output file




def processSheetnoHeader(eFile, sName, oFile, adjust_footer=False):
    print("Processing without header:", eFile)
    df = pd.read_excel(eFile, sheet_name=sName)
    rowHeader = findHeader(df)
    rowFooter = findFooter(df)
    if adjust_footer:
        rowFooter = rowFooter + 1
    StationRow = findStation(df)


    # Pull out station value for sheet if it exists
    if StationRow != False:
        station = df.iloc[StationRow, 0]
        start_index = station.find("Station: ") + len("Station: ")  # Index of 'A' in 'A21'
        end_index = station.find("-", start_index)  # Index of '-' character
        Station = station[start_index:end_index]


    df = pd.read_excel(eFile, sheet_name=sName, skiprows=rowHeader, skipfooter=rowFooter)
    if StationRow != False:
        df.insert(df.columns.get_loc("Prev Stn") + 1, 'Station', Station)
    df.rename(columns={'Trans Time': 'Transaction Time',
                       'Media\n': 'Media',
                       'Media ID\n': 'Media',
                       'Prev Stn': 'Previous Station',
                       'Trans Type': 'Transaction Type'},
              inplace=True)
    df = df[['Entry Time', 'Transaction Time', 'Previous Station', 'Station', 'Media', 'Transaction Type', 'Revenue']]
    df.to_csv(oFile, mode="a", index=False, header=False)  # Append without headers




# Consolidates multiple sheets
def consolidateMultipleSheetswithHeadersandFooters(fileList, folder_path, oFile):
    firstFile = fileList[0]


    for eFile in fileList:
        neweFile = os.path.join(folder_path, eFile)  # Combine the folder path with the file name


        print("Processing File:" + str(neweFile))
        dfChecks = pd.ExcelFile(neweFile)
        numSheets = len(dfChecks.sheet_names) + 1


        # Determine if we need to adjust the footer rows
        adjust_footer = True if numSheets == 3 else False


        # If file is the first file, pull out header
        if eFile == firstFile:
            # Check how many sheets are in the eFile
            for i in range(2, numSheets):
                print(i)
                cSheet = "Sheet" + str(i)
                if i == 2:
                    processSheetwithHeader(neweFile, cSheet, oFile, adjust_footer)
                else:
                    processSheetnoHeader(neweFile, cSheet, oFile, adjust_footer)
        else:
            for i in range(2, numSheets):
                print(i)
                cSheet = "Sheet" + str(i)
                processSheetnoHeader(neweFile, cSheet, oFile, adjust_footer)



# Takes a folder as an input and consolidates all excel files
def consolidateFolder(folder_path):
    # Get the list of all files in the folder
    fileList = [file for file in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, file))]
   
    # Define the output file path for the consolidated CSV file
    output_file = os.path.join(folder_path, "consolidated_data.csv")  # Output file remains constant
   
    # Call the consolidate function, passing the list of files and the output file path
    consolidateMultipleSheetswithHeadersandFooters(fileList, folder_path, output_file)  # Pass the folder path and output file directly
   
    return output_file  # Return the path to the consolidated CSV file



# To Run:
consolidateFolder(r'C:\Users\mvalsania25\Desktop\Destination_X')
# Out:
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITEERIA 03.19.2023.xls
# 2
# Processing with header: C:\Users\mvalsania25\Desktop\Destination_X\CRITEERIA 03.19.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA    08-26-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA    08-26-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA   06.18.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA   06.18.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA   08.30.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA   08.30.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA  11.05.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA  11.05.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA  11.08.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA  11.08.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA  11.15.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA  11.15.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA  12.08.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA  12.08.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA -08-27-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA -08-27-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02-08-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02-08-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02-17-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02-17-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02-18-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02-18-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02-19-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02-19-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02-25-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02-25-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02-26-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02-26-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02.10.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02.10.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02.12.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02.12.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02.15.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02.15.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02.22.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02.22.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02.24.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 02.24.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03-01-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03-01-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03-03-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03-03-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.08.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.08.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.10.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.10.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.15.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.15.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.17.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.17.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.22.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.22.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.24.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.24.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.26.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.26.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.29.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.29.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.31.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 03.31.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04-05-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04-05-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04-09-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04-09-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04-16-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04-16-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04-21-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04-21-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04.02.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04.02.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04.12.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04.12.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04.14.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04.14.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04.26.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04.26.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04.28.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04.28.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04.29.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04.29.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04.30.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 04.30.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.03.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.03.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.05.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.05.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.11.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.11.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.12.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.12.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.14.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.14.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.17.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.17.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.19.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.19.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.20.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.20.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.21.203.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.21.203.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.26.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.26.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.28.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.28.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.31.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 05.31.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06-16-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06-16-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.02.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.02.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.03..2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.03..2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.09.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.09.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.10.203.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.10.203.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.11.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.11.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.14.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.14.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.21.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.21.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.23.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.23.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.24.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.24.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.25.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.25.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.28.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.28.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.30.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 06.30.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.05.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.05.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.07.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.07.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.08.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.08.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.09.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.09.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.12.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.12.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.16.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.16.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.19.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.19.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.21.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.21.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.22.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.22.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.23.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.23.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.26.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.26.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.28.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.28.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.30.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 07.30.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.02.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.02.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.04.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.04.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.09.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.09.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.11.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.11.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.14.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.14.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.18.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.18.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.19.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.19.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.20.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.20.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.21.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.21.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.23.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.23.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.25.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 08.25.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 09.06.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 09.06.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 09.13.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 09.13.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 09.20.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 09.20.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 09.24.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 09.24.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 09.27.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 09.27.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.01.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.01.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.04.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.04.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.08.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.08.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.11.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.11.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.15.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.15.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.16.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.16.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.20.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.20.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.22.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.22.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.26.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.26.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.29.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 10.29.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 11-26-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 11-26-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 11.01.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 11.01.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 11.03.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 11.03.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 11.12.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 11.12.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 11.19.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 11.19.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 11.23.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 11.23.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 11.29.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 11.29.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 12.06.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 12.06.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 12.10.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 12.10.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 12.13.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 12.13.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 12.14.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 12.14.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 12.17.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITERIA 12.17.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\CRITIERA 04.23.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\CRITIERA 04.23.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail 10-11-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail 10-11-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_          06-19-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_          06-19-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_        07-27-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_        07-27-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_        09-20-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_        09-20-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_   CRITERIA 08.06.2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_   CRITERIA 08.06.2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ 01-05-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ 01-05-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ 03-20-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ 03-20-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ 07-31-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ 07-31-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ 10-27-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ 10-27-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ 12-05-20222.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ 12-05-20222.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CITERIA 11-27-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CITERIA 11-27-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-01-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-01-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-08-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-08-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-11-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-11-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-13-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-13-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-14-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-14-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-15-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-15-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-18-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-18-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-20-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-20-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-22-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-22-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-27-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-27-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-28-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-28-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-29-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 01-29-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 02-03-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 02-03-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 1-04-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 1-04-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 1-06-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 1-06-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 10-12-22.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 10-12-22.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 10-5-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 10-5-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-06-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-06-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-09-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-09-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-11-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-11-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-13-22.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-13-22.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-20-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-20-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-23-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-23-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-25-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-25-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-28-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-28-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-4-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 11-4-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-04-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-04-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-07-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-07-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-09-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-09-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-10-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-10-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-11-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-11-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-14-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-14-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-18-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-18-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-25-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-25-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-28-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 12-28-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 7-17-22.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_ CRITERIA 7-17-22.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_01-25-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_01-25-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_10-02-2022.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_10-02-2022.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CREITERIA_10-07-2023.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CREITERIA_10-07-2023.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRIERTIA 10.24.2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRIERTIA 10.24.2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRIERTIA 11.30.2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRIERTIA 11.30.2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01-03-2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01-03-2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01-17-2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01-17-2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01-24-2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01-24-2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01-26-2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01-26-2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01-31-2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01-31-2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.12.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.12.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.14.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.14.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.15.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.15.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.16.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.16.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.17.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.17.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.18.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.18.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.19.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.19.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.24.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.24.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.25.2025_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.25.2025_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.31.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 01.31.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02-04-2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02-04-2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02-07-2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02-07-2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02-11-23_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02-11-23_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02-14-23_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02-14-23_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02-21-23_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02-21-23_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02-28-23_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02-28-23_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.01.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.01.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.02.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.02.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.07.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.07.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.13.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.13.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.14.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.14.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.20.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.20.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.21.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.21.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.27.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.27.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.28.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.28.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.29.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 02.29.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03-11-23_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03-11-23_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03-18-2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03-18-2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03-21-2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03-21-2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03-25-2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03-25-2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03-28-2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03-28-2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03-4-2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03-4-2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.04.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.04.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.05.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.05.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.06.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.06.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.07.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.07.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.12.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.12.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.13.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.13.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.19.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.19.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.20.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.20.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.26.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.26.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.27.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 03.27.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04-1-2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04-1-2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04-4-2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04-4-2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.04.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.04.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.05.2024.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.05.2024.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.08.2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.08.2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.08.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.08.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.09.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.09.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.10.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.10.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.11.2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.11.2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.11.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.11.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.12.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.12.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.15.2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.15.2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.17.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.17.2024_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.18.2023_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.18.2023_.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.18.2024_.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA 04.18.2024_.xls
# ...
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA_3-31-24.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA_3-31-24.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA_4-2-2024.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA_4-2-2024.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA_7-21-24.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA_7-21-24.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA_7-23-24.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA_7-23-24.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__1.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__1.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__10.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__10.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__11.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__11.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__12.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__12.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__13.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__13.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__14.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__14.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__15.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__15.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__16.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__16.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__17.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__17.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__18.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__18.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__19.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__19.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__2.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__2.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__20.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__20.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__21.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__21.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__23.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__23.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__25.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__25.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__26.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__26.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__27.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__27.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__28.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__28.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__29.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__29.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__3.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__3.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__30.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__30.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__31.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__31.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__32.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__32.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__33.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__33.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__34.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__34.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__35.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__35.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__36.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__36.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__37.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__37.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__38.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__38.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__39.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__39.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__4.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__4.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__40.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__40.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__41.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__41.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__42.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__42.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__43.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__43.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__44.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__44.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__45.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__45.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__46.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__46.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__47.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__47.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__48.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__48.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__49.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__49.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__5.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__5.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__50.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__50.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__51.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__51.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__52.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__52.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__53.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__53.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__54.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__54.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__55.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__55.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__56.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__56.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__57.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__57.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__58.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__58.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__59.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__59.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__6.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__6.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__60.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__60.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__61.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__61.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__62.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__62.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__63.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__63.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__64.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__64.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__65.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__65.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__66.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__66.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__67.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__67.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__68.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__68.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__7.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__7.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__8.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__8.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__9.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERIA__9.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERITA_05-26-2024.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITERITA_05-26-2024.xls
# Processing File:C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITIERIA 09.07.2023_20230908011020.xls
# 2
# Processing without header: C:\Users\mvalsania25\Desktop\Destination_X\Revenue Transaction Detail_CRITIERIA 09.07.2023_20230908011020.xls
# 'C:\\Users\\mvalsania25\\Desktop\\Destination_X\\consolidated_data.csv'
